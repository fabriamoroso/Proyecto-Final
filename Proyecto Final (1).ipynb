# %% [markdown]
# # Entrega final curso Data Science Coder House
# Proyecto: Analisis de Correlacion del rinde de cosechas y distintas variables del cultivo
#
# El objetivo de este proyecto es intentar mediante metodos que aplicaria un/a Data Scientist determinar la posibilidad de prediccion de una problematica.
#
# El proyecto contara de distintas etapas.
# 1- Presentar problema el cual vamos a trabajar. Aqui se presentaran los datos que se encontraron y determinar cuales son los mas utiles y cuales no.
# 2- Armado de un Dataset con el cual procederemos a trabajar , se haran analisis exploratorios y se estableceran correlaciones entre los datos de haberlas.
# 3- Se utilizaran herramientas de Machine learning para predecir la variable que nos interesa saber.

# %% [markdown]
# # Problema
# Se intentara encontrar una correlacion entre el rinde de distintos cultivos con diversas variables obtenidas a traves de
# distintos informes proporcionados por entes guvernamentales, se trabajara con los datos de la Provincia de Buenos aires y
# se propondra un modelo de machine learning que permita hacer un analisis predictivo de cuanto sera el rinde de los mismos.

# %%
#COMENZAMOS IMPORTANDO LAS LIBRERIAS NECESARIAS PARA EL COMIENZO (LUEGO SE AGREGARAN OTRAS SEGUN SE NECESITE)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# Luego comenzamos a hacer un analisis de nuestro dataset e intentamos comprender los datos y como se comportan.

# %%
#Se importa el dataset de estimaciones de la Provincia y se genera una separacion para unicamente ver el cultivo Girasol
# y a partir de este cultivo intentar ver el comportamiento de los datos y asi tener una mejor comprension.

df_estimacion = pd.read_csv("Estimaciones (Provincia de BsAs 1987-2022).csv", encoding='latin-1', sep=";")
df_estimacion
# Out:
#            Cultivo  Campaña     Provincia  Departamento  idProvincia  \
# 0              Ajo  1987/88  BUENOS AIRES     ARRECIFES            6
# 1              Ajo  1987/88  BUENOS AIRES  BAHIA BLANCA            6
# 2              Ajo  1987/88  BUENOS AIRES      BALCARCE            6
# 3              Ajo  1989/90  BUENOS AIRES      BALCARCE            6
# 4              Ajo  1990/91  BUENOS AIRES      BALCARCE            6
# ...            ...      ...           ...           ...          ...
# 29214  Trigo total  2017/18  BUENOS AIRES        ZARATE            6
# 29215  Trigo total  2018/19  BUENOS AIRES        ZARATE            6
# 29216  Trigo total  2019/20  BUENOS AIRES        ZARATE            6
# 29217  Trigo total  2020/21  BUENOS AIRES        ZARATE            6
# 29218  Trigo total  2021/22  BUENOS AIRES        ZARATE            6
#
#        idDepartamento  Sup. Sembrada Sup. Cosechada Producción Rendimiento
# 0                  77             10             10         35        3500
# 1                  56             10             10         30        3000
# 2                  63            258            258        910        3527
# 3                  63             50             50        250        5000
# 4                  63             80             80        400        5000
# ...               ...            ...            ...        ...         ...
# 29214             882           1950           1950       8385        4300
# 29215             882           2800           2800      12320        4400
# 29216             882           2500           2500      10000        4000
# 29217             882           3000           3000      11700        3900
# 29218             882           7552           7552      36250        4800
#
# [29219 rows x 10 columns]

# %%
girasol= df_estimacion.loc[:, 'Cultivo'] == 'Girasol'
df_girasol=df_estimacion.loc[girasol]

# %%
#Traemos el data de Girasol, en el que usaremos unicamente la campaña 2021/22 para realizar una demostracion del analisis
#general, pero en menor escala, y realizamos 2 correciones que nos serviran a futuro: ponemos de indice Departamento, ademas 
#convertimos la columna Rendimiento, de String a Float.

girasol= df_girasol.loc[:, 'Campaña'] == '2021/22'
df_uc=df_girasol.loc[girasol]
df_uc.index = df_uc["Departamento"]
df_uc['Rendimiento'] = df_uc['Rendimiento'].astype(float)
df_uc
# Out:
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\848457928.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uc['Rendimiento'] = df_uc['Rendimiento'].astype(float)
#                         Cultivo  Campaña     Provincia  \
# Departamento
# 25 DE MAYO              Girasol  2021/22  BUENOS AIRES
# 9 DE JULIO              Girasol  2021/22  BUENOS AIRES
# ADOLFO ALSINA           Girasol  2021/22  BUENOS AIRES
# ADOLFO GONZALES CHAVES  Girasol  2021/22  BUENOS AIRES
# ARRECIFES               Girasol  2021/22  BUENOS AIRES
# ...                         ...      ...           ...
# TORNQUIST               Girasol  2021/22  BUENOS AIRES
# TRENQUE LAUQUEN         Girasol  2021/22  BUENOS AIRES
# TRES ARROYOS            Girasol  2021/22  BUENOS AIRES
# TRES LOMAS              Girasol  2021/22  BUENOS AIRES
# VILLARINO               Girasol  2021/22  BUENOS AIRES
#
#                                   Departamento  idProvincia  idDepartamento  \
# Departamento
# 25 DE MAYO                          25 DE MAYO            6             854
# 9 DE JULIO                          9 DE JULIO            6             588
# ADOLFO ALSINA                    ADOLFO ALSINA            6               7
# ADOLFO GONZALES CHAVES  ADOLFO GONZALES CHAVES            6              14
# ARRECIFES                            ARRECIFES            6              77
# ...                                        ...          ...             ...
# TORNQUIST                            TORNQUIST            6             819
# TRENQUE LAUQUEN                TRENQUE LAUQUEN            6             826
# TRES ARROYOS                      TRES ARROYOS            6             833
# TRES LOMAS                          TRES LOMAS            6             847
# VILLARINO                            VILLARINO            6             875
#
#                         Sup. Sembrada Sup. Cosechada Producción  Rendimiento
# Departamento
# 25 DE MAYO                      10536          10452      22601       2162.0
# 9 DE JULIO                       2000           2000       5400       2700.0
# ADOLFO ALSINA                   44000          44000      92400       2100.0
# ADOLFO GONZALES CHAVES          11061          11061      20684       1870.0
# ARRECIFES                        1529           1529       4434       2900.0
# ...                               ...            ...        ...          ...
# TORNQUIST                        3000           3000       5400       1800.0
# TRENQUE LAUQUEN                 35547          35547      95977       2700.0
# TRES ARROYOS                    88155          88155     172784       1960.0
# TRES LOMAS                      21000          21000      47670       2270.0
# VILLARINO                        2500           2500       3225       1290.0
#
# [92 rows x 10 columns]

# %%
#El primer grafico nos muestra un analisis que indica el Rendimiento en cada uno de los Departamentos, en la campaña 2021/22.
#Al ser tantos departamentos, algunos nombres se sobreponen, estamos intentado distintas maneras de que se vea de buena manera

fig, ax = plt.subplots(figsize=(50,15))
ax.bar(df_uc["Departamento"], df_uc['Rendimiento'])
ax.set_title('Rendimiento por departamento campaña 2021/22',fontsize=35)
ax.set_ylabel('Rendimiento',fontsize=35)
ax.set_xlabel('Departamento',fontsize=35)
ax.legend(fontsize=40) 
plt.xticks(rotation = 90)
plt.xticks(fontsize = 25,weight='bold')
plt.yticks(fontsize = 25, weight='bold')


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Al igual que anteriormente, utilizaremos la campaña 2021/22 para hacer un analisis a menor escala de lo que sera el analisis
#del proyecto final. En este caso generamos un data en el que nos muestra todos los cultivos, no solamente el Girasol, en ese
#año.

cultivo= df_estimacion.loc[:, 'Campaña'] == '2021/22'
df_cultivo=df_estimacion.loc[cultivo]
df_cultivo['Rendimiento'] = df_cultivo['Rendimiento'].astype(float)
df_cultivo
# Out:
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\772658127.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cultivo['Rendimiento'] = df_cultivo['Rendimiento'].astype(float)
#            Cultivo  Campaña     Provincia            Departamento  \
# 34         Alpiste  2021/22  BUENOS AIRES              25 DE MAYO
# 70         Alpiste  2021/22  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 72         Alpiste  2021/22  BUENOS AIRES                 ALBERTI
# 107        Alpiste  2021/22  BUENOS AIRES                AYACUCHO
# 142        Alpiste  2021/22  BUENOS AIRES                    AZUL
# ...            ...      ...           ...                     ...
# 29086  Trigo total  2021/22  BUENOS AIRES         TRENQUE LAUQUEN
# 29121  Trigo total  2021/22  BUENOS AIRES            TRES ARROYOS
# 29148  Trigo total  2021/22  BUENOS AIRES              TRES LOMAS
# 29183  Trigo total  2021/22  BUENOS AIRES               VILLARINO
# 29218  Trigo total  2021/22  BUENOS AIRES                  ZARATE
#
#        idProvincia  idDepartamento  Sup. Sembrada Sup. Cosechada Producción  \
# 34               6             854             82             82        103
# 70               6              14           1362           1362       2043
# 72               6              21             90             90        225
# 107              6              42            980            980       1470
# 142              6              49           2573           2573       3088
# ...            ...             ...            ...            ...        ...
# 29086            6             826          49142          49142     235882
# 29121            6             833         117946         117946     484392
# 29148            6             847          11100          11100      37700
# 29183            6             875          15305          10655      12803
# 29218            6             882           7552           7552      36250
#
#        Rendimiento
# 34          1256.0
# 70          1500.0
# 72          2500.0
# 107         1500.0
# 142         1200.0
# ...            ...
# 29086       4800.0
# 29121       4107.0
# 29148       3396.0
# 29183       1202.0
# 29218       4800.0
#
# [905 rows x 10 columns]

# %%
#El grafico muestra un analisis de cada cultivo en la campaña 2021/22, y su rendimiento en cada departamento, que no esta
#diferenciado, ya que la intencion no es ver cada departamento, si no tener graficamente un promedio (ver donde hay mas puntos)
#del rendimiento de cada cultivo en este año.

fig, ax = plt.subplots(figsize=(30,15))  
mapeo_colores = ax.scatter(df_cultivo['Cultivo'], df_cultivo['Rendimiento'])
fig.colorbar(mapeo_colores)
ax.set_title('Rendimiento Cultivo/Departamento')
ax.set_xlabel("Cultivo",fontsize=25)
ax.set_ylabel('Rendimiento',fontsize=25)
ax.legend(fontsize=25) 
plt.xticks(rotation = 60)
plt.xticks(fontsize = 15, weight='bold')
plt.yticks(fontsize = 15, weight='bold')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Se genera el Df del departamento de Rivadavia, teniendo en cuenta unicamente la siembra de Girasol. 

girasol_est= df_girasol.loc[:, 'Departamento'] == 'RIVADAVIA'
df_girasol_riv=df_girasol.loc[girasol_est]
df_girasol_riv.index = df_girasol_riv["Campaña"]
df_girasol_riv['Rendimiento'] = df_girasol_riv['Rendimiento'].astype(float)
# Out:
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\2271615594.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_girasol_riv['Rendimiento'] = df_girasol_riv['Rendimiento'].astype(float)

# %%
#Se genera el Df del departamento de Saavedra, teniendo en cuenta unicamente la siembra de Girasol. 

girasol_est2= df_girasol.loc[:, 'Departamento'] == 'SAAVEDRA'
df_girasol_saa=df_girasol.loc[girasol_est2]
df_girasol_saa.index = df_girasol_saa["Campaña"]
df_girasol_saa['Rendimiento'] = df_girasol_saa['Rendimiento'].astype(float)
df_girasol_saa.head()
# Out:
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\1772361696.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_girasol_saa['Rendimiento'] = df_girasol_saa['Rendimiento'].astype(float)
#          Cultivo  Campaña     Provincia Departamento  idProvincia  \
# Campaña
# 1987/88  Girasol  1987/88  BUENOS AIRES     SAAVEDRA            6
# 1988/89  Girasol  1988/89  BUENOS AIRES     SAAVEDRA            6
# 1989/90  Girasol  1989/90  BUENOS AIRES     SAAVEDRA            6
# 1990/91  Girasol  1990/91  BUENOS AIRES     SAAVEDRA            6
# 1991/92  Girasol  1991/92  BUENOS AIRES     SAAVEDRA            6
#
#          idDepartamento  Sup. Sembrada Sup. Cosechada Producción  Rendimiento
# Campaña
# 1987/88             700          38500          38500      54000       1403.0
# 1988/89             700          40000          39000      50000       1282.0
# 1989/90             700          35000          35000      60000       1714.0
# 1990/91             700          25000          25000      42500       1700.0
# 1991/92             700          25000          25000      33800       1352.0

# %%
#Se muestran los rendimientos en el transcurso del periodo entre las campañas 1987/88 y 2021/22 de los departamentos de
#Rivadavia y Saavedra, en el que muestra una clara superioridad, exceptuando en 2 campañas, del depto. de Rivadavia. 
#Con esto se realizan 2 analisis bivariados sobre un mismo grafico, en el que el departamento no lo tomamos como un dato
#analizado, ya que unicamente esta ahi de referencia.

fig, ax = plt.subplots(figsize=(45, 20))  
ax.plot(df_girasol_riv.index, df_girasol_riv['Rendimiento'], label='Rendimiento de Girasol en el depto. de Rivadavia')
ax.plot(df_girasol_saa.index, df_girasol_saa['Rendimiento'], label='Rendimiento de Girasol en el depto. de Saavedra', color='C1')
ax.set_xlabel('Año', fontsize=30)  
ax.set_ylabel('Rendimiento', fontsize=30) 
ax.set_title('Rendimiento de Girasol en los deptos. de Rivadavia y Saavedra', fontsize=25)
ax.legend(fontsize=30) 
plt.xticks(fontsize = 20, weight='bold')
plt.xticks(rotation = 60)
plt.yticks(fontsize = 20, weight='bold')
plt.show()

# %% [markdown]
# Esta primera exploracion nos hizo dar cuenta como se conformaban los datos, cuales eran relevantes y que habia algunos que nos faltaban para terminar de entender ciertos comportamientos, por eso luego de esto se consiguio un dataset de clima de la provincia de dos regiones distintas, se tranformo y se adapto para cada tipo de cultivo teniendo en cuenta las precipitaciones recibidas durante su siembra (que es la principal variable climatica que afecta a los cultivos).

# %% [markdown]
# Se consiguen 2 datos climaticos para dos zonas muy distintas geografica y climaticamente hablando, Junin (zona norte) y Tres
# Arroyos (zona sur). A partir de ahora se trabajan con dataset adaptados a estas localidades y sus cultivos, se pone como ejemplo uno de los tratamientos de datos y luego se pasa al Dataset final.

# %%
df = pd.read_csv("Estimaciones (Provincia de BsAs 1987-2022).csv", encoding='latin-1', sep=";")
df
# Out:
#            Cultivo  Campaña     Provincia  Departamento  idProvincia  \
# 0              Ajo  1987/88  BUENOS AIRES     ARRECIFES            6
# 1              Ajo  1987/88  BUENOS AIRES  BAHIA BLANCA            6
# 2              Ajo  1987/88  BUENOS AIRES      BALCARCE            6
# 3              Ajo  1989/90  BUENOS AIRES      BALCARCE            6
# 4              Ajo  1990/91  BUENOS AIRES      BALCARCE            6
# ...            ...      ...           ...           ...          ...
# 29214  Trigo total  2017/18  BUENOS AIRES        ZARATE            6
# 29215  Trigo total  2018/19  BUENOS AIRES        ZARATE            6
# 29216  Trigo total  2019/20  BUENOS AIRES        ZARATE            6
# 29217  Trigo total  2020/21  BUENOS AIRES        ZARATE            6
# 29218  Trigo total  2021/22  BUENOS AIRES        ZARATE            6
#
#        idDepartamento  Sup. Sembrada Sup. Cosechada Producción Rendimiento
# 0                  77             10             10         35        3500
# 1                  56             10             10         30        3000
# 2                  63            258            258        910        3527
# 3                  63             50             50        250        5000
# 4                  63             80             80        400        5000
# ...               ...            ...            ...        ...         ...
# 29214             882           1950           1950       8385        4300
# 29215             882           2800           2800      12320        4400
# 29216             882           2500           2500      10000        4000
# 29217             882           3000           3000      11700        3900
# 29218             882           7552           7552      36250        4800
#
# [29219 rows x 10 columns]

# %%
df["Cultivo"].value_counts()
# Out:
# Maíz                3302
# Trigo total         3285
# Girasol             3159
# Soja total          3060
# Avena               2983
# Soja 1ra            2053
# Sorgo               1972
# Soja 2da            1915
# Cebada cervecera    1724
# Alpiste              800
# Trigo candeal        754
# Colza                747
# Centeno              667
# Lino                 615
# Cebada total         569
# Mijo                 515
# Cebada forrajera     390
# Arveja               172
# Papa total           124
# Cebolla total         55
# Limón                 52
# Naranja               50
# Mandarina             49
# Pomelo                46
# Maní                  44
# Lenteja               37
# Ajo                   32
# Cártamo               18
# Garbanzo              17
# Poroto seco           13
# Name: Cultivo, dtype: int64

# %%
#Se eligen las zonas mas cercanas a Tres Arroyos 
df_TA= df[df.Departamento.isin(["SAN CAYETANO", "ADOLFO GONZALES CHAVES","CORONEL PRINGLES","BENITO JUAREZ","LAPRIDA","CORONEL DORREGO","TRES ARROYOS"])]
df_TA.sample(30)
# Out:
#                 Cultivo  Campaña     Provincia            Departamento  \
# 20252        Soja total  1992/93  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 18760          Soja 2da  2007/08  BUENOS AIRES         CORONEL DORREGO
# 4093   Cebada cervecera  1995/96  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 1856              Avena  2010/11  BUENOS AIRES        CORONEL PRINGLES
# 23102        Soja total  1988/89  BUENOS AIRES            TRES ARROYOS
# 4566   Cebada cervecera  2008/09  BUENOS AIRES        CORONEL PRINGLES
# 9070            Girasol  2003/04  BUENOS AIRES         CORONEL DORREGO
# 16416          Soja 1ra  2011/12  BUENOS AIRES           BENITO JUAREZ
# 1833              Avena  2019/20  BUENOS AIRES         CORONEL DORREGO
# 14915              Maíz  2008/09  BUENOS AIRES            SAN CAYETANO
# 21028        Soja total  1990/91  BUENOS AIRES        CORONEL PRINGLES
# 12419              Maíz  1995/96  BUENOS AIRES           BENITO JUAREZ
# 26063       Trigo total  2011/12  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 8560            Girasol  1994/95  BUENOS AIRES           BENITO JUAREZ
# 25396     Trigo candeal  1992/93  BUENOS AIRES        CORONEL PRINGLES
# 26335       Trigo total  2003/04  BUENOS AIRES           BENITO JUAREZ
# 25224     Trigo candeal  2010/11  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 4525   Cebada cervecera  1996/97  BUENOS AIRES         CORONEL DORREGO
# 20258        Soja total  1998/99  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 4932   Cebada cervecera  2009/10  BUENOS AIRES                 LAPRIDA
# 12948              Maíz  1999/00  BUENOS AIRES         CORONEL DORREGO
# 25376     Trigo candeal  2002/03  BUENOS AIRES         CORONEL DORREGO
# 22829        Soja total  1997/98  BUENOS AIRES            SAN CAYETANO
# 8151              Colza  2012/13  BUENOS AIRES            TRES ARROYOS
# 60              Alpiste  2011/12  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 258             Alpiste  2011/12  BUENOS AIRES         CORONEL DORREGO
# 9863            Girasol  2014/15  BUENOS AIRES                 LAPRIDA
# 21780        Soja total  2015/16  BUENOS AIRES                 LAPRIDA
# 20280        Soja total  2020/21  BUENOS AIRES  ADOLFO GONZALES CHAVES
# 735             Alpiste  2020/21  BUENOS AIRES            SAN CAYETANO
#
#        idProvincia  idDepartamento  Sup. Sembrada Sup. Cosechada Producción  \
# 20252            6              14           7000           4900       3400
# 18760            6             189          12000           3600       1469
# 4093             6              14          10000          10000      23000
# 1856             6             196          32850          13150      23670
# 23102            6             833           1000           1000       1200
# 4566             6             196           3600           3600       6840
# 9070             6             189          38000          38000      53000
# 16416            6              84          68000          66000     158400
# 1833             6             189          29800           4800       9600
# 14915            6             742           6500           4500      15800
# 21028            6             196           1500           1500       2700
# 12419            6              84           7000           5600      16800
# 26063            6              14          70000          70000     299560
# 8560             6              84          11000          10450      20900
# 25396            6             196           1200           1200       2500
# 26335            6              84          52000          51300     205200
# 25224            6              14           1950           1950       8385
# 4525             6             189          49000          41000      90200
# 20258            6              14           2500           1700       2200
# 4932             6             448           1000           1000       1800
# 12948            6             189           6000           1200       4800
# 25376            6             189          10500           9500      21850
# 22829            6             742           1500           1400       2400
# 8151             6             833           1000           1000       1600
# 60               6              14            400            400        640
# 258              6             189            100            100        140
# 9863             6             448           5800           5800       9860
# 21780            6             448          10700          10700      28400
# 20280            6              14          65500          65500     104050
# 735              6             742           1600           1600       3680
#
#       Rendimiento
# 20252         694
# 18760         408
# 4093         2300
# 1856         1800
# 23102        1200
# 4566         1900
# 9070         1395
# 16416        2400
# 1833         2000
# 14915        3511
# 21028        1800
# 12419        3000
# 26063        4279
# 8560         2000
# 25396        2083
# 26335        4000
# 25224        4300
# 4525         2200
# 20258        1294
# 4932         1800
# 12948        4000
# 25376        2300
# 22829        1714
# 8151         1600
# 60           1600
# 258          1400
# 9863         1700
# 21780        2654
# 20280        1589
# 735          2300

# %%
# Se borran las columnas con datos innecesarios
df_TA= df_TA.drop(['Provincia', 'idProvincia',"Departamento"], axis=1)
df_TA
# Out:
#            Cultivo  Campaña  idDepartamento  Sup. Sembrada Sup. Cosechada  \
# 20             Ajo  1995/96             833              4              4
# 36         Alpiste  1987/88              14           2000           2000
# 37         Alpiste  1988/89              14           3000           3000
# 38         Alpiste  1989/90              14           2000           2000
# 39         Alpiste  1990/91              14           1800           1700
# ...            ...      ...             ...            ...            ...
# 29117  Trigo total  2017/18             833         105070         105070
# 29118  Trigo total  2018/19             833          89875          80875
# 29119  Trigo total  2019/20             833         119000         119000
# 29120  Trigo total  2020/21             833         131000         131000
# 29121  Trigo total  2021/22             833         117946         117946
#
#       Producción Rendimiento
# 20            16        4000
# 36          2400        1200
# 37          2250         750
# 38          2400        1200
# 39          1700        1000
# ...          ...         ...
# 29117     514843        4900
# 29118     339453        4197
# 29119     393100        3303
# 29120     570000        4351
# 29121     484392        4107
#
# [2396 rows x 7 columns]

# %%
#Se eligen los cultivos relevantes 
df_TA= df_TA[df_TA.Cultivo.isin(["Alpiste","Trigo candeal","Cebada cervecera","Arveja", "Avena","Cebada total","Centeno",'Trigo total','Girasol','Maíz','Soja 1ra','Soja 2da','Sorgo'])]
df_TA
# Out:
#            Cultivo  Campaña  idDepartamento  Sup. Sembrada Sup. Cosechada  \
# 36         Alpiste  1987/88              14           2000           2000
# 37         Alpiste  1988/89              14           3000           3000
# 38         Alpiste  1989/90              14           2000           2000
# 39         Alpiste  1990/91              14           1800           1700
# 40         Alpiste  1991/92              14           1000           1000
# ...            ...      ...             ...            ...            ...
# 29117  Trigo total  2017/18             833         105070         105070
# 29118  Trigo total  2018/19             833          89875          80875
# 29119  Trigo total  2019/20             833         119000         119000
# 29120  Trigo total  2020/21             833         131000         131000
# 29121  Trigo total  2021/22             833         117946         117946
#
#       Producción Rendimiento
# 36          2400        1200
# 37          2250         750
# 38          2400        1200
# 39          1700        1000
# 40           950         950
# ...          ...         ...
# 29117     514843        4900
# 29118     339453        4197
# 29119     393100        3303
# 29120     570000        4351
# 29121     484392        4107
#
# [1981 rows x 7 columns]

# %%
# Se sacan todos los valores invalidos de todas las columnas si los hubiese
df_TA['Rendimiento'].replace('SD', '0', inplace=True)
df_TA['Sup. Sembrada'].replace('SD', '0', inplace=True)
df_TA['Sup. Cosechada'].replace('SD', '0', inplace=True)
df_TA['Producción'].replace('SD', '0', inplace=True)
df_TA
# Out:
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\206192072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TA['Rendimiento'].replace('SD', '0', inplace=True)
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\206192072.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TA['Sup. Sembrada'].replace('SD', '0', inplace=True)
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\206192072.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TA['Sup. Cosechada'].replace('SD', '0', inplace=True)
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\206192072.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TA['Producción'].replace('SD', '0', inplace=True)
#            Cultivo  Campaña  idDepartamento  Sup. Sembrada Sup. Cosechada  \
# 36         Alpiste  1987/88              14           2000           2000
# 37         Alpiste  1988/89              14           3000           3000
# 38         Alpiste  1989/90              14           2000           2000
# 39         Alpiste  1990/91              14           1800           1700
# 40         Alpiste  1991/92              14           1000           1000
# ...            ...      ...             ...            ...            ...
# 29117  Trigo total  2017/18             833         105070         105070
# 29118  Trigo total  2018/19             833          89875          80875
# 29119  Trigo total  2019/20             833         119000         119000
# 29120  Trigo total  2020/21             833         131000         131000
# 29121  Trigo total  2021/22             833         117946         117946
#
#       Producción Rendimiento
# 36          2400        1200
# 37          2250         750
# 38          2400        1200
# 39          1700        1000
# 40           950         950
# ...          ...         ...
# 29117     514843        4900
# 29118     339453        4197
# 29119     393100        3303
# 29120     570000        4351
# 29121     484392        4107
#
# [1981 rows x 7 columns]

# %%
df_TA.rename(columns={"Sup. Sembrada":"Sup_Sembrada","Sup. Cosechada":"Sup_Cosechada"}, inplace=True)
# Out:
# C:\Users\syluv\AppData\Local\Temp\ipykernel_4524\4212525572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TA.rename(columns={"Sup. Sembrada":"Sup_Sembrada","Sup. Cosechada":"Sup_Cosechada"}, inplace=True)

# %%
#Se pasa a valor codificado la columna Cultivo
df_TA=df_TA.replace({"Alpiste": 101, "Arveja": 102,'Avena': 103, 'Cebada cervecera': 105, 'Cebada total': 107,
       'Centeno': 109, 'Girasol': 112, 'Maíz': 116, 'Soja 1ra': 124 , 'Soja 2da': 125, 'Sorgo': 127,
       'Trigo candeal': 128, 'Trigo total': 129})
df_TA
# Out:
#        Cultivo  Campaña  idDepartamento  Sup_Sembrada Sup_Cosechada  \
# 36         101  1987/88              14          2000          2000
# 37         101  1988/89              14          3000          3000
# 38         101  1989/90              14          2000          2000
# 39         101  1990/91              14          1800          1700
# 40         101  1991/92              14          1000          1000
# ...        ...      ...             ...           ...           ...
# 29117      129  2017/18             833        105070        105070
# 29118      129  2018/19             833         89875         80875
# 29119      129  2019/20             833        119000        119000
# 29120      129  2020/21             833        131000        131000
# 29121      129  2021/22             833        117946        117946
#
#       Producción Rendimiento
# 36          2400        1200
# 37          2250         750
# 38          2400        1200
# 39          1700        1000
# 40           950         950
# ...          ...         ...
# 29117     514843        4900
# 29118     339453        4197
# 29119     393100        3303
# 29120     570000        4351
# 29121     484392        4107
#
# [1981 rows x 7 columns]

# %%
anio= lambda x: x[:4]
df_TA["anio"]= df_TA["Campaña"].astype(str).map(anio)
df_TA.anio = df_TA.anio.astype(float)
df_TA
# Out:
#        Cultivo  Campaña  idDepartamento  Sup_Sembrada Sup_Cosechada  \
# 36         101  1987/88              14          2000          2000
# 37         101  1988/89              14          3000          3000
# 38         101  1989/90              14          2000          2000
# 39         101  1990/91              14          1800          1700
# 40         101  1991/92              14          1000          1000
# ...        ...      ...             ...           ...           ...
# 29117      129  2017/18             833        105070        105070
# 29118      129  2018/19             833         89875         80875
# 29119      129  2019/20             833        119000        119000
# 29120      129  2020/21             833        131000        131000
# 29121      129  2021/22             833        117946        117946
#
#       Producción Rendimiento    anio
# 36          2400        1200  1987.0
# 37          2250         750  1988.0
# 38          2400        1200  1989.0
# 39          1700        1000  1990.0
# 40           950         950  1991.0
# ...          ...         ...     ...
# 29117     514843        4900  2017.0
# 29118     339453        4197  2018.0
# 29119     393100        3303  2019.0
# 29120     570000        4351  2020.0
# 29121     484392        4107  2021.0
#
# [1981 rows x 8 columns]

# %% [markdown]
# Luego se prepara el set de datos de precipitaciones y se acomoda el tema de las columnas para que no haya valores duplicados o innecesarios, se termina de dar forma al dataset final.

# %%
df_eta=pd.read_excel("tres_arroyos.xlsx")
df_eta=df_eta.replace({"Alpiste": 101, "Arveja": 102,'Avena': 103, 'Cebada cervecera': 105, 'Cebada total': 107,
       'Centeno': 109, 'Girasol': 112, 'Maíz': 116, 'Soja 1ra': 124 , 'Soja 2da': 125, 'Sorgo': 127,
       'Trigo candeal': 128, 'Trigo total': 129})
df_eta
# Out:
#       Unnamed: 0  Cultivo  anio  idDepartamento  Sup_Sembrada  Sup_Cosechada  \
# 0             36      101  1987              14          2000           2000
# 1             37      101  1988              14          3000           3000
# 2             38      101  1989              14          2000           2000
# 3             39      101  1990              14          1800           1700
# 4             40      101  1991              14          1000           1000
# ...          ...      ...   ...             ...           ...            ...
# 1976       29117      129  2017             833        105070         105070
# 1977       29118      129  2018             833         89875          80875
# 1978       29119      129  2019             833        119000         119000
# 1979       29120      129  2020             833        131000         131000
# 1980       29121      129  2021             833        117946         117946
#
#       Producción  Rendimiento
# 0           2400         1200
# 1           2250          750
# 2           2400         1200
# 3           1700         1000
# 4            950          950
# ...          ...          ...
# 1976      514843         4900
# 1977      339453         4197
# 1978      393100         3303
# 1979      570000         4351
# 1980      484392         4107
#
# [1981 rows x 8 columns]

# %%
df_cta=pd.read_excel("ClimaTA trabajado.xlsx")
df_cta=df_cta.rename(columns={"Alpiste": 101, "Arveja": 102,'avena': 103, 'cebada cervecera': 105, 'cebada': 107,
       'centeno': 109, 'girasol': 112, 'Maiz': 116, 'soja 1': 124 , 'soja2': 125, 'Sorgo': 127,
       'trigo candeal': 128, 'trigo': 129})
df_cta
# Out:
#     anio    101    102    109    105    107    103    128    129    125  \
# 0   1988  243.6  211.2  244.5  243.6  243.6  243.6  304.1  304.1  245.4
# 1   1989  333.3  229.7  359.3  333.3  333.3  333.3  550.3  550.3  675.7
# 2   1990  277.8  516.8  278.1  277.8  277.8  277.8  366.9  366.9  379.1
# 3   1991  263.4  485.4  435.0  263.4  263.4  263.4  474.6  474.6  461.1
# 4   1992  343.4  437.3  388.2  343.4  343.4  343.4  453.1  453.1  436.1
# 5   1993  253.8  525.0  346.0  253.8  253.8  253.8  398.5  398.5  370.9
# 6   1994  279.1  346.2  326.4  279.1  279.1  279.1  461.4  461.4  522.8
# 7   1995  282.9  216.6  291.7  282.9  282.9  282.9  348.1  348.1  413.3
# 8   1996  237.4  394.5  249.8  237.4  237.4  237.4  406.8  406.8  566.9
# 9   1997  377.8  352.6  491.7  377.8  377.8  377.8  533.1  533.1  567.8
# 10  1998  219.7  255.0  234.5  219.7  219.7  219.7  255.5  255.5  280.7
# 11  1999  272.3  244.3  288.8  272.3  272.3  272.3  395.9  395.9  513.4
# 12  2000  360.4  449.0  382.9  360.4  360.4  360.4  424.9  424.9  552.8
# 13  2001  476.5  680.3  540.7  476.5  476.5  476.5  610.7  610.7  473.5
# 14  2002  573.4  459.1  590.4  573.4  573.4  573.4  630.7  630.7  202.2
# 15  2003  329.4  372.7  339.8  329.4  329.4  329.4  446.5  446.5  392.3
# 16  2004  383.8  301.7  402.1  383.8  383.8  383.8  543.3  543.3  514.3
# 17  2005  299.0  355.5  312.6  299.0  299.0  299.0  387.9  387.9  341.5
# 18  2006  283.9  426.2  302.5  283.9  283.9  283.9  426.5  426.5  420.8
# 19  2007  316.4  294.0  318.2  316.4  316.4  316.4  335.5  335.5  370.9
# 20  2008  149.2  257.7  180.0  149.2  149.2  149.2  219.9  219.9  286.3
# 21  2009  226.3  592.3  281.1  226.3  226.3  226.3  342.3  342.3  537.0
# 22  2010  400.5  273.2  443.4  400.5  400.5  400.5  491.3  491.3  380.7
# 23  2011  282.8  348.0  327.8  282.8  282.8  282.8  458.2  458.2  391.0
# 24  2012  395.6  707.4  428.1  395.6  395.6  395.6  601.1  601.1  457.0
# 25  2013  327.9  376.5  332.4  327.9  327.9  327.9  349.6  349.6  385.6
# 26  2014  581.0  548.6  668.0  581.0  581.0  581.0  807.5  807.5  440.4
# 27  2015  275.9  668.1  297.3  275.9  275.9  275.9  423.1  423.1  452.1
# 28  2016  136.0  322.2  173.1  136.0  136.0  136.0  216.5  216.5  373.4
# 29  2017  310.6  385.0  371.9  310.6  310.6  310.6  419.1  419.1  284.0
# 30  2018  351.3  387.7  373.8  351.3  351.3  351.3  440.8  440.8  333.3
# 31  2019  212.0  420.0  278.0  212.0  212.0  212.0  395.4  395.4  462.9
# 32  2020  308.4  372.4  435.6  308.4  308.4  308.4  503.3  503.3  377.7
# 33  2021  225.2  260.5  249.1  225.2  225.2  225.2  288.5  288.5  353.6
#
#       124    112    127    116
# 0   302.9  332.5  498.4  558.2
# 1   645.3  557.1  784.3  894.1
# 2   459.2  446.8  608.1  632.3
# 3   514.4  435.1  716.8  827.7
# 4   511.9  358.8  746.9  759.0
# 5   507.9  467.3  680.0  703.3
# 6   619.6  452.4  680.5  692.1
# 7   555.1  450.0  677.1  707.6
# 8   628.8  598.4  763.3  777.5
# 9   730.1  536.8  796.4  855.4
# 10  308.3  116.0  344.6  508.9
# 11  611.7  498.5  678.3  737.5
# 12  583.7  481.5  827.7  894.9
# 13  556.5  483.1  741.6  824.2
# 14  416.9  466.1  564.7  614.6
# 15  461.2  439.8  607.3  646.9
# 16  576.3  648.5  699.1  768.0
# 17  450.5  455.5  514.5  572.3
# 18  436.7  464.0  661.6  696.1
# 19  415.6  363.9  544.7  703.8
# 20  307.7  179.6  388.0  425.4
# 21  615.1  551.0  722.0  765.5
# 22  526.9  481.9  630.9  691.3
# 23  553.0  439.8  691.0  727.5
# 24  605.4  476.9  675.7  697.6
# 25  443.6  279.5  599.0  698.8
# 26  558.7  621.4  800.7  831.7
# 27  500.3  481.1  668.1  689.6
# 28  394.9  279.5  538.3  568.6
# 29  358.8  320.9  441.6  497.1
# 30  482.6  450.2  571.7  645.7
# 31  503.1  370.7  627.1  683.9
# 32  484.9  394.8  598.7  630.1
# 33  406.6  283.3  497.6  560.6

# %%
#usamos la funcion .melt para rotar las columnas y que queden igual al dataframe del rendimiento
df_cta=pd.melt(df_cta, id_vars = ["anio"])
df_cta
# Out:
#      anio variable  value
# 0    1988      101  243.6
# 1    1989      101  333.3
# 2    1990      101  277.8
# 3    1991      101  263.4
# 4    1992      101  343.4
# ..    ...      ...    ...
# 437  2017      116  497.1
# 438  2018      116  645.7
# 439  2019      116  683.9
# 440  2020      116  630.1
# 441  2021      116  560.6
#
# [442 rows x 3 columns]

# %%
df_cta= df_cta.rename(columns={'variable':'Cultivo',"value":"Precipitacion"})
df_cta
# Out:
#      anio Cultivo  Precipitacion
# 0    1988     101          243.6
# 1    1989     101          333.3
# 2    1990     101          277.8
# 3    1991     101          263.4
# 4    1992     101          343.4
# ..    ...     ...            ...
# 437  2017     116          497.1
# 438  2018     116          645.7
# 439  2019     116          683.9
# 440  2020     116          630.1
# 441  2021     116          560.6
#
# [442 rows x 3 columns]

# %%
new_df2 = pd.merge(df_eta, df_cta,  how='left', left_on=['anio','Cultivo'], right_on = ['anio','Cultivo'])
new_df2
# Out:
#       Unnamed: 0 Cultivo  anio  idDepartamento  Sup_Sembrada  Sup_Cosechada  \
# 0             36     101  1987              14          2000           2000
# 1             37     101  1988              14          3000           3000
# 2             38     101  1989              14          2000           2000
# 3             39     101  1990              14          1800           1700
# 4             40     101  1991              14          1000           1000
# ...          ...     ...   ...             ...           ...            ...
# 1976       29117     129  2017             833        105070         105070
# 1977       29118     129  2018             833         89875          80875
# 1978       29119     129  2019             833        119000         119000
# 1979       29120     129  2020             833        131000         131000
# 1980       29121     129  2021             833        117946         117946
#
#       Producción  Rendimiento  Precipitacion
# 0           2400         1200            NaN
# 1           2250          750          243.6
# 2           2400         1200          333.3
# 3           1700         1000          277.8
# 4            950          950          263.4
# ...          ...          ...            ...
# 1976      514843         4900          419.1
# 1977      339453         4197          440.8
# 1978      393100         3303          395.4
# 1979      570000         4351          503.3
# 1980      484392         4107          288.5
#
# [1981 rows x 9 columns]

# %% [markdown]
# una vez finalizado esto se repite para la otra zona geografica y asi llegamos finalmente al set de datos total con el cual trabajaremos

# %%
from utils import *
dfn = pd.read_excel("Datos_totales.xlsx")
dfn
# Out:
#       Unnamed: 0  Cultivo  idDepartamento  Sup_Sembrada  Sup_Cosechada  \
# 0              0      101             210            35             35
# 1              1      101             462            50             50
# 2              2      101             462            50             50
# 3              3      101             469           150            130
# 4              4      101             469           120            120
# ...          ...      ...             ...           ...            ...
# 3379        1925      129             833        105070         105070
# 3380        1926      129             833         89875          80875
# 3381        1927      129             833        119000         119000
# 3382        1928      129             833        131000         131000
# 3383        1929      129             833        117946         117946
#
#       Producción  Rendimiento  anio  Precipitacion
# 0             56         1600  2021          257.7
# 1             70         1400  1988          199.6
# 2             40          800  1989          180.5
# 3            190         1462  1988          199.6
# 4            168         1400  1989          180.5
# ...          ...          ...   ...            ...
# 3379      514843         4900  2017          419.1
# 3380      339453         4197  2018          440.8
# 3381      393100         3303  2019          395.4
# 3382      570000         4351  2020          503.3
# 3383      484392         4107  2021          288.5
#
# [3384 rows x 9 columns]

# %%
#borramos la columna Unnamed
del(dfn['Unnamed: 0'])

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3384 entries, 0 to 3383
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cultivo         3384 non-null   int64
#  1   idDepartamento  3384 non-null   int64
#  2   Sup_Sembrada    3384 non-null   int64
#  3   Sup_Cosechada   3384 non-null   int64
#  4   Producción      3384 non-null   int64
#  5   Rendimiento     3384 non-null   int64
#  6   anio            3384 non-null   int64
#  7   Precipitacion   3384 non-null   float64
# dtypes: float64(1), int64(7)
# memory usage: 211.6 KB

# %%
#vemos un poco los datos y como se distribuyen
dfn.describe()
# Out:
#            Cultivo  idDepartamento   Sup_Sembrada  Sup_Cosechada  \
# count  3384.000000     3384.000000    3384.000000    3384.000000
# mean    115.909574      417.029551   23898.095154   22276.288121
# std      10.153570      262.042090   35967.720110   35537.353342
# min     101.000000       14.000000      15.000000       0.000000
# 25%     105.000000      196.000000    1900.000000    1000.000000
# 50%     116.000000      448.000000   10000.000000    6860.000000
# 75%     125.000000      686.000000   31000.000000   29100.000000
# max     129.000000      833.000000  265000.000000  265000.000000
#
#           Producción   Rendimiento        anio  Precipitacion
# count    3384.000000   3384.000000  3384.00000    3384.000000
# mean    68289.342199   2971.283688  2005.80792     512.867524
# std    111853.381132   1936.930244     9.55206     244.432019
# min         0.000000      0.000000  1988.00000     116.000000
# 25%      2420.000000   1704.000000  1998.00000     335.500000
# 50%     16830.000000   2500.000000  2006.00000     450.500000
# 75%     87155.750000   3800.000000  2014.00000     643.200000
# max    884440.000000  13886.000000  2021.00000    1447.500000

# %%
#hacemos un heat map para ver si hay correlaciones entre algunas de las columnas
plt.figure(figsize=(15,15))
cor=dfn.corr()
sns.heatmap(cor, annot=True, linewidths=2)
plt.show()

# %%
# Como nuestra busqueda se centra en intentar ver la relacion entre las precipitaciones y el rendimiento 
# vemos su relacion en grafico
plt.scatter(dfn["Precipitacion"], dfn["Rendimiento"])
plt.xlabel("Precipitaciones (mm)")
plt.ylabel("Rendimiento cultivo")
plt.show()

# %%
#hacemos un joinplot para ver mejor como se distribuyen las variables rendimiento y precipitaciones
jointplot=sns.jointplot(data=dfn, x="Precipitacion", y ="Rendimiento")
jointplot.plot_joint(sns.kdeplot, levels=5)
jointplot.fig.set_figwidth(15)

# %%
# Gráfico de distribución para cada variable numérica
# ==============================================================================
# Ajustar número de subplots en función del número de columnas
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(13, 7))
axes = axes.flat
columnas_numeric = dfn.select_dtypes(include=['float64', 'int']).columns
columnas_numeric = columnas_numeric.drop('Rendimiento')

for i, colum in enumerate(columnas_numeric):
    sns.regplot(
        x           = dfn[colum],
        y           = dfn['Rendimiento'],
        color       = "gray",
        marker      = '.',
        scatter_kws = {"alpha":0.4},
        line_kws    = {"color":"r","alpha":0.7},
        ax          = axes[i]
    )
    axes[i].set_title(f"Rendimiento vs {colum}", fontsize = 7, fontweight = "bold")
    #axes[i].ticklabel_format(style='sci', scilimits=(-4,4), axis='both')
    axes[i].yaxis.set_major_formatter
    axes[i].xaxis.set_major_formatter
    axes[i].tick_params(labelsize = 6)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")

# Se eliminan los axes vacíos
for i in [8]:
    fig.delaxes(axes[i])
    
fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Correlación con Rendimiento', fontsize = 10, fontweight = "bold");

# %%
#Vemos la distribucion de nuestra variable objetivo.
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.distplot(
    dfn.Rendimiento,
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('Rendimiento', fontsize='small') 
axes[0].tick_params(labelsize = 6)

sns.distplot(
    np.sqrt(dfn.Rendimiento),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(Rendimiento)', fontsize='small') 
axes[1].tick_params(labelsize = 6)

sns.distplot(
    np.log(dfn.Rendimiento),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(Rendimiento)', fontsize='small') 
axes[2].tick_params(labelsize = 6)

fig.tight_layout()
# Out:
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Diego\miniconda3\envs\Mientorno\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Se observa que la distrución de la variable "Rendimiento", y tiene una distribución bastante simétrica y se decide explorarla sin transformarla.

# %%
#Definimos nuestra variable objetivo y separamos el Dataset para el entrenamiento
X = dfn.drop("Rendimiento", axis=1)
y=df_data.Rendimiento

# %%
#importamos el train test split y separamos el dataset para entrenamiento y testeo
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
#comenzamos utilizando un modelo de regresion lineal y medir el tiempo de cada algoritmo

inicio = time.time()
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
fin = time.time()
print(fin-inicio)
# Out:
# 0.0064928531646728516

# %%
#Hacemos nuestras predicciones
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([3983.02784215, 3761.61941507, 2514.49764019, ..., 4293.80630092,
#        2282.29657192, 2778.04498848])

# %%
#Armamos un Df comparativo
comp=pd.DataFrame({"real": y_test, "preds":y_pred})
comp
# Out:
#       real        preds
# 569   2800  3983.027842
# 3340  3584  3761.619415
# 1850  2100  2514.497640
# 1412  4200  4251.029516
# 2202  1851  1897.669536
# ...    ...          ...
# 2347  1200 -1073.251137
# 1588  1000  2342.336752
# 2521  4500  4293.806301
# 154   3100  2282.296572
# 480   1802  2778.044988
#
# [1016 rows x 2 columns]

# %% [markdown]
# Calculamos el R2 (utilizaremos esta medida para ver el grado de error) El coeficiente de determinación, o R² está estrechamente relacionada con la MSE,tiene la ventaja de estar libre de escala R2=1-(MSE(modelo)/MSE(baseline))

# %% [markdown]
# Tambien calcularemos el MAE, Esta métrica de regresión es el valor medio de la diferencia absoluta entre el valor real y el valor predicho.

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
r2= r2_score(y_test,y_pred)
r2
# Out:
# 0.5692360295452686

# %%
MAE= mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 956.6075301946563

# %% [markdown]
# Ahora probaremos otros modelos y compararemos

# %%
#Probamos el Decision tree Regressor

inicio = time.time()
from sklearn.tree import DecisionTreeRegressor
model2=DecisionTreeRegressor(random_state=1)
model2.fit(X_train, y_train)
fin = time.time()
print(fin-inicio)
# Out:
# 2.672492027282715

# %%
y_pred2=model2.predict(X_test)
comp2=pd.DataFrame({"real": y_test, "pred":y_pred2})
comp2
# Out:
#       real    pred
# 569   2800  2300.0
# 3340  3584  4300.0
# 1850  2100  2500.0
# 1412  4200  3800.0
# 2202  1851  1901.0
# ...    ...     ...
# 2347  1200  1767.0
# 1588  1000  1000.0
# 2521  4500  5000.0
# 154   3100  2500.0
# 480   1802  1600.0
#
# [1016 rows x 2 columns]

# %%
r2= r2_score(y_test,y_pred2)
r2
# Out:
# 0.8760844227425268

# %%
MAE= mean_absolute_error(y_test,y_pred2)
MAE
# Out:
# 413.81003937007875

# %%
#Probaremos el Random Forest Regressor

inicio = time.time()
from sklearn.ensemble import RandomForestRegressor
model3=RandomForestRegressor(random_state=1)
model3.fit(X_train, y_train)
fin = time.time()
print(fin-inicio)
# Out:
# 1.2299349308013916

# %%
y_pred3=model3.predict(X_test)
comp3=pd.DataFrame({"real": y_test, "pred":y_pred3})
comp3
# Out:
#       real     pred
# 569   2800  2639.30
# 3340  3584  3879.00
# 1850  2100  2324.65
# 1412  4200  3994.67
# 2202  1851  1860.05
# ...    ...      ...
# 2347  1200  1688.60
# 1588  1000   991.06
# 2521  4500  5062.09
# 154   3100  2634.00
# 480   1802  1897.84
#
# [1016 rows x 2 columns]

# %%
r2= r2_score(y_test,y_pred3)
r2
# Out:
# 0.9385249085840909

# %%
MAE= mean_absolute_error(y_test,y_pred3)
MAE
# Out:
# 287.58753937007873

# %%
inicio = time.time()
from sklearn import svm
svm_reg= svm.SVR()
regressor=svm_reg.fit(X_train, y_train)
y_pred4=regressor.predict(X_test)
fin = time.time()
print(fin-inicio)
# Out:
# 0.5543186664581299

# %%
comp4=pd.DataFrame({"real": y_test, "pred":y_pred4})
comp4.sample(10)
# Out:
#       real         pred
# 1219  6000  2493.024821
# 560   3000  2497.828305
# 2352  2100  2717.749064
# 180   3000  2492.753225
# 2505  2000  2492.104923
# 304   2100  2492.990553
# 1070  4000  2601.129031
# 1386  2308  2645.433571
# 1403  4000  2670.080865
# 3360  2695  2693.714792

# %%
r2= r2_score(y_test,y_pred4)
r2
# Out:
# 0.00829438521136816

# %%
MAE= mean_absolute_error(y_test,y_pred4)
MAE
# Out:
# 1278.7359151975875

# %%
inicio = time.time()
from sklearn.neighbors import KNeighborsRegressor
KNN_reg=KNeighborsRegressor(n_neighbors=5)
regressor=KNN_reg.fit(X_train, y_train)
y_pred5=regressor.predict(X_test)
fin = time.time()
print(fin-inicio)
# Out:
# 0.01399087905883789

# %%
comp5=pd.DataFrame({"real": y_test, "pred":y_pred5})
comp5.sample(10)
# Out:
#       real    pred
# 2489  6300  5930.8
# 557   2097  2326.6
# 2275  1026  1122.8
# 2349  1200  1184.6
# 2351  2000  2132.4
# 3137  3600  3640.2
# 2640  1000  1040.0
# 2259  1500  1530.8
# 2206  1300  1359.0
# 1448  4700  4712.0

# %%
r2= r2_score(y_test,y_pred5)
r2
# Out:
# 0.9429521773711178

# %%
MAE= mean_absolute_error(y_test,y_pred5)
MAE
# Out:
# 254.28405511811022

# %%
#Probamos algunas tecnicas de Stacking (Ensamblar mas de 1 modelo para mejorar un resultado)
#Definimos que modelos vamos a combinar
lr = LinearRegression()
knn = KNeighborsRegressor(n_neighbors=5)
rf = RandomForestRegressor(random_state=1)

# %%
# Se combinan los modelos
estimators = [("Linear Regression", lr), ("KNN", knn), ("Random Forest", rf)]

# %%
#importamos la tecnica de ensamble
from sklearn.ensemble import StackingRegressor

# %%
#Define the super model whit a meta-stimator which is just another linear regression
inicio = time.time()
ensemble= StackingRegressor(estimators=estimators, final_estimator=lr)
#entrenamos el super-modelo
ensemble.fit(X_train, y_train)
fin = time.time()
print(fin-inicio)
# Out:
# 4.128875255584717

# %%
#entrenamos el super-modelo
ensemble.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('Linear Regression', LinearRegression()),
#                               ('KNN', KNeighborsRegressor()),
#                               ('Random Forest',
#                                RandomForestRegressor(random_state=1))],
#                   final_estimator=LinearRegression())

# %%
#evaluamos el super-modelo
y_pred_ens=ensemble.predict(X_test)

# %%
#vemos algunos resultados
comp_ens=pd.DataFrame({"real": y_test, "pred":y_pred_ens})
comp_ens.sample(10)
# Out:
#       real         pred
# 644   6400  7186.046494
# 3225  1750  2199.693977
# 58    3000  2736.745720
# 558   2191  2106.639180
# 1305  3949  3756.256549
# 2223  1700  1657.130205
# 931   4696  4303.681984
# 2398  3196  2906.377152
# 1670  2000  2069.627214
# 825   7245  6732.670311

# %%
#calculamos nuestro R2 del super-modelo
r2= r2_score(y_test,y_pred_ens)
r2
# Out:
# 0.9617729521609623

# %%
MAE= mean_absolute_error(y_test,y_pred_ens)
MAE
# Out:
# 225.81021488624876

# %% [markdown]
# Se logro una mejora importante con el ensamble de modelos pero vemos a un costo computacional alto

# %%
from sklearn import model_selection
from sklearn.metrics import r2_score

# %%
#ahora probamos un K-Cross validation para ver si el modelo responde de la misma manera siempre
models = []
models.append(('lr', LinearRegression()))
models.append(('knn' , KNeighborsRegressor(n_neighbors=5)))
models.append(('rf' , RandomForestRegressor(random_state=1)))
models.append(('ensemble', StackingRegressor(estimators=estimators, final_estimator=lr)))
print(models)
# Out:
# [('lr', LinearRegression()), ('knn', KNeighborsRegressor()), ('rf', RandomForestRegressor(random_state=1)), ('ensemble', StackingRegressor(estimators=[('Linear Regression', LinearRegression()),
#                               ('KNN', KNeighborsRegressor()),
#                               ('Random Forest',
#                                RandomForestRegressor(random_state=1))],
#                   final_estimator=LinearRegression()))]

# %%
results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=6, random_state=None)
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring='r2')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# lr: 0.602194 (0.033904)
# knn: 0.925834 (0.023977)
# rf: 0.928368 (0.021614)
# ensemble: 0.950300 (0.017024)

# %%
results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=6, random_state=None)
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring='neg_mean_absolute_error')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# lr: -940.907836 (40.218469)
# knn: -286.319414 (33.575917)
# rf: -302.895812 (21.768300)
# ensemble: -242.176284 (17.323367)

# %% [markdown]
# Observamosque luego de correr el K-fold CrossValidation en un split de 6, luego de entrenar varias veces las prubas siguen siendo consistentes, tanto para el modelo de ensamble como los otros modelos y sus metricas.

# %%
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
# Realizamos una PowerTransformation para evaluar como actuan los algoritmos

# %%
from sklearn.preprocessing import PowerTransformer
power_transformer = PowerTransformer(method='yeo-johnson')

# %%
X_trans = X.copy(deep=True)
X_trans = power_transformer.fit_transform(X_trans)

# %%
X_train_trans, X_test_trans, y_train_trans, y_test_trans = train_test_split(X_trans, y, test_size=0.2, random_state=1)

# %%
inicio = time.time()
model_3 = LinearRegression()
model_3.fit(X_train_trans, y_train_trans)
fin = time.time()
print(fin-inicio)
# Out:
# 0.008086919784545898

# %%
yhat_trans = model_3.predict(X_test_trans)

# %%
import sklearn.metrics as metrics
r2_3 = metrics.r2_score(y_test_trans, yhat_trans)
print('R Square: %3f' % r2_3)
# Out:
# R Square: 0.882409

# %%
MAE= mean_absolute_error(y_test_trans,yhat_trans)
MAE
# Out:
# 453.9367251721169

# %%
inicio = time.time()
from sklearn.tree import DecisionTreeRegressor
model4=DecisionTreeRegressor(random_state=1)
model4.fit(X_train_trans, y_train_trans)
fin = time.time()
print(fin-inicio)
# Out:
# 0.022867202758789062

# %%
y_pred8=model4.predict(X_test_trans)
comp8=pd.DataFrame({"real": y_test_trans, "pred":y_pred8})
comp8
# Out:
#       real    pred
# 569   2800  2800.0
# 3340  3584  3400.0
# 1850  2100  2400.0
# 1412  4200  4000.0
# 2202  1851  1901.0
# ...    ...     ...
# 2149  1200  1200.0
# 3231  1700  1967.0
# 260   3800  3000.0
# 584   2769  2714.0
# 2798  1500   800.0
#
# [677 rows x 2 columns]

# %%
r2= r2_score(y_test_trans,y_pred8)
r2
# Out:
# 0.8954715965413244

# %%
MAE= mean_absolute_error(y_test_trans,y_pred8)
MAE
# Out:
# 372.4505169867061

# %%
inicio = time.time()
from sklearn.ensemble import RandomForestRegressor
model19=RandomForestRegressor(random_state=1)
model19.fit(X_train_trans, y_train_trans)
fin = time.time()
print(fin-inicio)
# Out:
# 0.9293441772460938

# %%
y_pred19=model19.predict(X_test_trans)
comp19=pd.DataFrame({"real": y_test_trans, "pred":y_pred19})
comp19
# Out:
#       real     pred
# 569   2800  2590.00
# 3340  3584  3728.96
# 1850  2100  2311.22
# 1412  4200  4031.60
# 2202  1851  1830.06
# ...    ...      ...
# 2149  1200  1481.69
# 3231  1700  2113.15
# 260   3800  3470.17
# 584   2769  2411.37
# 2798  1500  1419.38
#
# [677 rows x 2 columns]

# %%
r2= r2_score(y_test_trans,y_pred19)
r2
# Out:
# 0.9546617999599815

# %%
MAE= mean_absolute_error(y_test_trans,y_pred19)
MAE
# Out:
# 254.99847858197927

# %%
inicio = time.time()
from sklearn import svm
svm_reg= svm.SVR()
regressor=svm_reg.fit(X_train_trans, y_train_trans)
y_pred20=regressor.predict(X_test_trans)
fin = time.time()
print(fin-inicio)
# Out:
# 0.5717027187347412

# %%
comp20=pd.DataFrame({"real": y_test_trans, "pred":y_pred20})
comp20.sample(10)
# Out:
#       real         pred
# 898   3850  2701.660242
# 2306  1600  2586.054785
# 255   3100  2423.468559
# 1219  6000  2548.207694
# 3233  2788  2563.607381
# 1008  2780  2682.914266
# 602   3500  2553.076239
# 605   2200  2528.239050
# 2019  2412  2435.784315
# 17    3400  2479.909863

# %%
r2= r2_score(y_test_trans,y_pred20)
r2
# Out:
# -0.011092807749869094

# %%
MAE= mean_absolute_error(y_test_trans,y_pred20)
MAE
# Out:
# 1289.814461991256

# %%
inicio = time.time()
from sklearn.neighbors import KNeighborsRegressor
KNN_reg=KNeighborsRegressor(n_neighbors=5)
regressor=KNN_reg.fit(X_train_trans, y_train_trans)
y_pred21=regressor.predict(X_test_trans)
fin = time.time()
print(fin-inicio)
# Out:
# 0.023999452590942383

# %%
comp21=pd.DataFrame({"real": y_test_trans, "pred":y_pred21})
comp21.sample(10)
# Out:
#       real    pred
# 2640  1000   992.0
# 3294  2791  2755.6
# 1961  3100  3300.0
# 314   3300  2801.4
# 2223  1700  4040.0
# 958   3800  4163.0
# 1002  2500  2300.0
# 303   2700  2160.0
# 3018  2000  1957.0
# 1519  1200  1720.0

# %%
r2= r2_score(y_test_trans,y_pred21)
r2
# Out:
# 0.8623913282227649

# %%
MAE= mean_absolute_error(y_test_trans,y_pred21)
MAE
# Out:
# 489.5657311669128

# %% [markdown]
# Ahora se procede a comparar los tiempos, R2, MAE de cada Algoritmo y su transformación
# Se realizo dos DataFrame con los resultados

# %%
df_rrss = pd.read_csv("df_rrss.csv")
df_rrss
# Out:
#    Unnamed: 0 method    time      R2      MAE
# 0           0     LN  0.0064  0.5692   956.60
# 1           1    DTR  2.6724  0.8760   413.81
# 2           2    RFR  1.2299  0.9385   287.58
# 3           3    SVM  0.5543  0.0082  1278.73
# 4           4    KNN  0.0139  0.9429   254.28
# 5           5    ESM  4.1288  0.9617   225.81

# %%
df_rrss = df_rrss.drop("Unnamed: 0", axis=1)
df_rrss
# Out:
#   method    time      R2      MAE
# 0     LN  0.0064  0.5692   956.60
# 1    DTR  2.6724  0.8760   413.81
# 2    RFR  1.2299  0.9385   287.58
# 3    SVM  0.5543  0.0082  1278.73
# 4    KNN  0.0139  0.9429   254.28
# 5    ESM  4.1288  0.9617   225.81

# %%
df_rrss2 = pd.read_csv("df_rrss2.csv")
df_rrss2
# Out:
#    Unnamed: 0  method     time      R2      MAE
# 0           0   OP_LN  0.00800  0.8824   453.93
# 1           1  OP_DTR  0.02286  0.8954   372.45
# 2           2  OP_RFR  0.92930  0.9546   254.99
# 3           3  OP_SVM  0.57170 -0.0110  1289.81
# 4           4  OP_KNN  0.02390  0.8623   489.56

# %%
df_rrss2 = df_rrss2.drop("Unnamed: 0", axis=1)
df_rrss2
# Out:
#    method     time      R2      MAE
# 0   OP_LN  0.00800  0.8824   453.93
# 1  OP_DTR  0.02286  0.8954   372.45
# 2  OP_RFR  0.92930  0.9546   254.99
# 3  OP_SVM  0.57170 -0.0110  1289.81
# 4  OP_KNN  0.02390  0.8623   489.56

# %%
plt.plot(df_rrss.method, df_rrss.time, 'b-', marker='o' )
plt.xlabel('Algorithms')
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %%
plt.plot(df_rrss2.method, df_rrss2.time, 'b-', marker='o' )
plt.xlabel('Algorithms PowerT')
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %%
plt.plot(df_rrss.method, df_rrss.MAE, 'b-', marker='o' )
plt.xlabel('Algorithms')
plt.ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')

# %%
plt.plot(df_rrss2.method, df_rrss2.MAE, 'b-', marker='o' )
plt.xlabel('Algorithms PowerT')
plt.ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')

# %%
plt.plot(df_rrss.method, df_rrss.R2, 'b-', marker='o' )
plt.xlabel('Algorithms')
plt.ylabel("R2")
# Out:
# Text(0, 0.5, 'R2')

# %%
plt.plot(df_rrss2.method, df_rrss2.R2, 'b-', marker='o' )
plt.xlabel('Algorithms PowerT')
plt.ylabel("R2")
# Out:
# Text(0, 0.5, 'R2')

# %% [markdown]
# Se puede obserbar en las gráficas que el algoritmo mayor beneficiado con la transformación fue el LR, quien mejoro su R2 y MAE.  Asimismo por diferencia de computo y mejor R2 y MAE el KNN sigue obteniendo mejores valores.  Tambien debe tenerse en cuanto a performace en testing y k-fold el modelo de ensamble, si bien no tiene un tiempo optimo computacional, arroja los mejores resultados en las metricas.

# %%
comp_ens
plt.figure(figsize=(15,7.5))

sns.kdeplot(data=comp_ens, x='real', c='b', linewidth=2)
sns.kdeplot(data=comp_ens, x='pred', c='r', linewidth=2, linestyle='--')
plt.xlim(100,5000)
plt.title('Prediciones Vs Real - Modelo Ensamblado', fontsize=25)
plt.show()

# %% [markdown]
#   Realizamos la comparación de la mejor linea de predicción ya que un error de 225 kilos por hectarea no es representativo para el negocio. Otorgando una predicción muy aceptable.
#   En cuanto al tiempo de computo no es un inconveniente porque los plazos de cada cultivo otorga un margen considerable para el reproceso del mismo.  Ahora al uso de las variables utilizadas, y el tratamiento otorgado permitieron responder a la problematica planteada de predecir el rendimiento de los cultivos.
